# %% [markdown]
# ##### 4th Feb 2020, University of Burdwan
# # 3D plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = np.loadtxt("data_cosmo.txt")

ax = fig.add_subplot(111, projection='3d')

x = data[:,0]
y = data[:,1]
z = data[:,2]
#z_rev = z[::-1]
Y, Z = np.meshgrid(y, z)
X = np.matrix(x[:, np.newaxis])
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim(1000000,200000)
ax.set_zlim(0.0058, 0.0055)
ax.set_xlabel("momentum")
ax.set_ylabel("scalar spectral index")
ax.set_zlabel("tensor to scalar ratio")
surf = ax.plot_surface(X,Y,Z)
plt.savefig("plot_p", dpi = 1000)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = np.loadtxt("data_cosmo.txt")
ax = fig.add_subplot(111, projection='3d')

x1 = data[:,0]
x = x1/10000
y1 = data[:,1]
y = y1 * 1000
z1 = data[:,2]
z = z1 * 1000

#z_rev = z[::-1]
Y, Z = np.meshgrid(y, z)
X = np.matrix(x[:, np.newaxis])
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim(100,20)
ax.set_zlim(5.8, 5.5)
ax.set_xlabel("momentum")
ax.set_ylabel("scalar spectral index")
ax.set_zlabel("tensor to scalar ratio")
ax.plot_wireframe(X,Y,Z)
plt.savefig("plot_p1.jpeg", dpi = 500)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = np.loadtxt("data_cosmo.txt")
ax = fig.add_subplot(111, projection='3d')

x1 = data[:,0]
x = x1/10000
y1 = data[:,1]
y = y1 * 1000
z1 = data[:,2]
z = z1 * 1000

#z_rev = z[::-1]
Y, Z = np.meshgrid(y, z)
X = np.matrix(x[:, np.newaxis])
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim(100,20)
ax.set_zlim(5.8, 5.5)
ax.set_xlabel("momentum")
ax.set_ylabel("scalar spectral index")
ax.set_zlabel("tensor to scalar ratio")
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.hot)
plt.savefig("plot_p1.jpeg", dpi = 500)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


data = np.loadtxt("data_cosmo.txt")
ax = fig.add_subplot(111, projection='3d')

x1 = data[:,0]
x = x1/10000
y1 = data[:,1]
y = y1 * 1000
z1 = data[:,2]
z = z1 * 1000

#z_rev = z[::-1]
Y, Z = np.meshgrid(y, z)
X = np.matrix(x[:, np.newaxis])
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim(100,20)
ax.set_zlim(5.8, 5.5)
ax.set_xlabel("momentum (in K)")
ax.set_ylabel("scalar spectral index")
ax.set_zlabel("tensor to scalar ratio")
ax.plot_wireframe(X,Y,Z)
plt.savefig("plot_p1.jpeg", dpi = 500)
for i in range(0,360):
    ax.view_init(0,i)
    plt.show()

# %% [markdown]
# # 2D plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = np.loadtxt("data_cosmo.txt")

ax = fig.add_subplot(111, projection='3d')

x = data[:,0]
y = data[:,1]
z = data[:,2]
plt.plot(x,y)
plt.xlabel("momentum")
plt.ylabel("ssi")
plt.savefig("plot_2d_mom_ssi", dpi = 1000)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = np.loadtxt("data_cosmo.txt")

ax = fig.add_subplot(111, projection='3d')

x = data[:,0]
y = data[:,1]
z = data[:,2]
plt.plot(x,z)
plt.xlabel("momentum")
plt.ylabel("tsr")
plt.savefig("plot_2d_mom_tsr", dpi = 1000)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = np.loadtxt("data_cosmo.txt")

ax = fig.add_subplot(111, projection='3d')

x = data[:,0]
y = data[:,1]
z = data[:,2]
plt.plot(y,z)
plt.xlabel("ssi")
plt.ylabel("tsr")
plt.savefig("plot_2d_ssi_tsr", dpi = 1000)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = np.loadtxt("data_cosmo.txt")

ax = fig.add_subplot(111, projection='3d')

x = data[:,0]
y = data[:,1]
z = data[:,2]
plt.ylim(0.00554, 0.00559)
plt.plot(y,z)
plt.xlabel("ssi")
plt.ylabel("tsr")
#plt.xscale("log")
plt.savefig("plot_2d_ssi_tsr", dpi = 1000)
